# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_credits = pd.read_csv('the-movies-dataset/credits.csv')
df_keywords = pd.read_csv('the-movies-dataset/keywords.csv')
df_links = pd.read_csv('the-movies-dataset/links.csv')
df_ratings = pd.read_csv('the-movies-dataset/ratings.csv')
df_movies_meta = pd.read_csv('the-movies-dataset/movies_metadata.csv')
df_links_small = pd.read_csv('the-movies-dataset/links_small.csv')
df_ratings_small = pd.read_csv('the-movies-dataset/ratings_small.csv')
# Out:
# /home/romulo/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Data overview

# %%
print('CREDITS')
display(df_credits.head())
print('\n\nKEYWORDS')
display(df_keywords.head())
print('\n\nLINKS')
display(df_links.head())
display(df_links_small.head())
print('\n\nMOVIES')
display(df_movies_meta.head())
print('\n\nRATINGS')
display(df_ratings.head())
display(df_ratings_small.head())
# Out:
# CREDITS
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862
# KEYWORDS
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...
# LINKS
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0
# MOVIES
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview    ...     release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...    ...       1995-10-30
# 1  When siblings Judy and Peter discover an encha...    ...       1995-12-15
# 2  A family wedding reignites the ancient feud be...    ...       1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...    ...       1995-12-22
# 4  Just when George Banks has recovered from his ...    ...       1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]
# RATINGS
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205

# %%
df_movies_meta.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# ## Utils functions

# %%
def get_genres_from_row(row):
    aux_row = row[1:-1]
    raw_genres = aux_row.split('}')
    genres = list()
    for g in raw_genres:
        aux = g.split(':')
        if len(aux) >= 3:
            genre = aux[2].replace("'", "")
            genres.append(genre)
    return genres

# %%
def build_movie_attr_dict(movies_dict, attr):
    attr_dict = dict()
    for _id, movie_dict in movies_dict.items():
        movie_id = f"{_id}_{movie_dict['title']}"
        attr_dict[movie_id] = movie_dict[attr]
    return attr_dict

# %%
def sort_movies_by_attr(movies_dict, attr, desc=True):
    attr_dict = build_movie_attr_dict(movies_dict, attr)
    return {k: v for k, v in sorted(attr_dict.items(), key=lambda item: item[1], reverse=desc)}

# %% [markdown]
# ## Movies analysis

# %% [markdown]
# ** Análises usando uma variável **
# 1. filmes com maior receita.
# 2. filmes mais populares.
# 3. filmes com maior despesas.
# 4. filmes mais votados
# 5. filmes com maior média de avaliação.
# 6. distribuição por gênero
# 7. distribuição por tempo de filmes
#
#
# ** Análises usando duas variáveis **
# 1. Relação de receita por popularidade
# 2. Relação de receita por despesas
# 3. Relação de receita por média de avaliação
# 4. Relação de despesas por popularidade
# 5. Relação de despesas por média de avaliação
# 6. Relação de popularidade por média de avaliação.

# %%
aux_df = df_movies_meta.head(1000)
movies_dict = dict()

for i, row in aux_df.iterrows():
    id_movie = row['id']
    inner_dict = dict(
        title=row['original_title'],
        budget=row['budget'],
        vote_count=row['vote_count'],
        vote_avg=row['vote_average'],
        revenue=row['revenue'],
        genres=get_genres_from_row(row['genres']),
        runtime=row['runtime'],
        popularity=row['popularity']
    )
        
    movies_dict[id_movie] = inner_dict
display(movies_dict)
# Out:
# {'862': {'title': 'Toy Story',
#   'budget': '30000000',
#   'vote_count': 5415.0,
#   'vote_avg': 7.7,
#   'revenue': 373554033.0,
#   'genres': [' Animation', ' Comedy', ' Family'],
#   'runtime': 81.0,
#   'popularity': 21.946943},
#  '8844': {'title': 'Jumanji',
#   'budget': '65000000',
#   'vote_count': 2413.0,
#   'vote_avg': 6.9,
#   'revenue': 262797249.0,
#   'genres': [' Adventure', ' Fantasy', ' Family'],
#   'runtime': 104.0,
#   'popularity': 17.015539},
#  '15602': {'title': 'Grumpier Old Men',
#   'budget': '0',
#   'vote_count': 92.0,
#   'vote_avg': 6.5,
#   'revenue': 0.0,
#   'genres': [' Romance', ' Comedy'],
#   'runtime': 101.0,
#   'popularity': 11.7129},
#  '31357': {'title': 'Waiting to Exhale',
#   'budget': '16000000',
#   'vote_count': 34.0,
#   'vote_avg': 6.1,
#   'revenue': 81452156.0,
#   'genres': [' Comedy', ' Drama', ' Romance'],
#   'runtime': 127.0,
#   'popularity': 3.859495},
#  '11862': {'title': 'Father of the Bride Part II',
#   'budget': '0',
#   'vote_count': 173.0,
#   'vote_avg': 5.7,
#   'revenue': 76578911.0,
#   'genres': [' Comedy'],
#   'runtime': 106.0,
#   'popularity': 8.387519000000001},
#  '949': {'title': 'Heat',
#   'budget': '60000000',
#   'vote_count': 1886.0,
#   'vote_avg': 7.7,
#   'revenue': 187436818.0,
#   'genres': [' Action', ' Crime', ' Drama', ' Thriller'],
#   'runtime': 170.0,
#   'popularity': 17.924927},
#  '11860': {'title': 'Sabrina',
#   'budget': '58000000',
#   'vote_count': 141.0,
#   'vote_avg': 6.2,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Romance'],
#   'runtime': 127.0,
#   'popularity': 6.677277},
#  '45325': {'title': 'Tom and Huck',
#   'budget': '0',
#   'vote_count': 45.0,
#   'vote_avg': 5.4,
#   'revenue': 0.0,
#   'genres': [' Action', ' Adventure', ' Drama', ' Family'],
#   'runtime': 97.0,
#   'popularity': 2.5611610000000002},
#  '9091': {'title': 'Sudden Death',
#   'budget': '35000000',
#   'vote_count': 174.0,
#   'vote_avg': 5.5,
#   'revenue': 64350171.0,
#   'genres': [' Action', ' Adventure', ' Thriller'],
#   'runtime': 106.0,
#   'popularity': 5.23158},
#  '710': {'title': 'GoldenEye',
#   'budget': '58000000',
#   'vote_count': 1194.0,
#   'vote_avg': 6.6,
#   'revenue': 352194034.0,
#   'genres': [' Adventure', ' Action', ' Thriller'],
#   'runtime': 130.0,
#   'popularity': 14.686035999999998},
#  '9087': {'title': 'The American President',
#   'budget': '62000000',
#   'vote_count': 199.0,
#   'vote_avg': 6.5,
#   'revenue': 107879496.0,
#   'genres': [' Comedy', ' Drama', ' Romance'],
#   'runtime': 106.0,
#   'popularity': 6.318445},
#  '12110': {'title': 'Dracula: Dead and Loving It',
#   'budget': '0',
#   'vote_count': 210.0,
#   'vote_avg': 5.7,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Horror'],
#   'runtime': 88.0,
#   'popularity': 5.430331},
#  '21032': {'title': 'Balto',
#   'budget': '0',
#   'vote_count': 423.0,
#   'vote_avg': 7.1,
#   'revenue': 11348324.0,
#   'genres': [' Family', ' Animation', ' Adventure'],
#   'runtime': 78.0,
#   'popularity': 12.140733},
#  '10858': {'title': 'Nixon',
#   'budget': '44000000',
#   'vote_count': 72.0,
#   'vote_avg': 7.1,
#   'revenue': 13681765.0,
#   'genres': [' History', ' Drama'],
#   'runtime': 192.0,
#   'popularity': 5.092},
#  '1408': {'title': 'Cutthroat Island',
#   'budget': '98000000',
#   'vote_count': 137.0,
#   'vote_avg': 5.7,
#   'revenue': 10017322.0,
#   'genres': [' Action', ' Adventure'],
#   'runtime': 119.0,
#   'popularity': 7.284477000000001},
#  '524': {'title': 'Casino',
#   'budget': '52000000',
#   'vote_count': 1343.0,
#   'vote_avg': 7.8,
#   'revenue': 116112375.0,
#   'genres': [' Drama', ' Crime'],
#   'runtime': 178.0,
#   'popularity': 10.137389},
#  '4584': {'title': 'Sense and Sensibility',
#   'budget': '16500000',
#   'vote_count': 364.0,
#   'vote_avg': 7.2,
#   'revenue': 135000000.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 136.0,
#   'popularity': 10.673167},
#  '5': {'title': 'Four Rooms',
#   'budget': '4000000',
#   'vote_count': 539.0,
#   'vote_avg': 6.5,
#   'revenue': 4300000.0,
#   'genres': [' Crime', ' Comedy'],
#   'runtime': 98.0,
#   'popularity': 9.026586},
#  '9273': {'title': 'Ace Ventura: When Nature Calls',
#   'budget': '30000000',
#   'vote_count': 1128.0,
#   'vote_avg': 6.1,
#   'revenue': 212385533.0,
#   'genres': [' Crime', ' Comedy', ' Adventure'],
#   'runtime': 90.0,
#   'popularity': 8.205447999999999},
#  '11517': {'title': 'Money Train',
#   'budget': '60000000',
#   'vote_count': 224.0,
#   'vote_avg': 5.4,
#   'revenue': 35431113.0,
#   'genres': [' Action', ' Comedy', ' Crime'],
#   'runtime': 103.0,
#   'popularity': 7.337905999999999},
#  '8012': {'title': 'Get Shorty',
#   'budget': '30250000',
#   'vote_count': 305.0,
#   'vote_avg': 6.4,
#   'revenue': 115101622.0,
#   'genres': [' Comedy', ' Thriller', ' Crime'],
#   'runtime': 105.0,
#   'popularity': 12.669608},
#  '1710': {'title': 'Copycat',
#   'budget': '0',
#   'vote_count': 199.0,
#   'vote_avg': 6.5,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Thriller'],
#   'runtime': 124.0,
#   'popularity': 10.701801},
#  '9691': {'title': 'Assassins',
#   'budget': '50000000',
#   'vote_count': 394.0,
#   'vote_avg': 6.0,
#   'revenue': 30303072.0,
#   'genres': [' Action', ' Adventure', ' Crime', ' Thriller'],
#   'runtime': 132.0,
#   'popularity': 11.065939},
#  '12665': {'title': 'Powder',
#   'budget': '0',
#   'vote_count': 143.0,
#   'vote_avg': 6.3,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Fantasy', ' Science Fiction', ' Thriller'],
#   'runtime': 111.0,
#   'popularity': 12.133094},
#  '451': {'title': 'Leaving Las Vegas',
#   'budget': '3600000',
#   'vote_count': 365.0,
#   'vote_avg': 7.1,
#   'revenue': 49800000.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 112.0,
#   'popularity': 10.332025},
#  '16420': {'title': 'Othello',
#   'budget': '0',
#   'vote_count': 33.0,
#   'vote_avg': 7.0,
#   'revenue': 0.0,
#   'genres': [' Drama'],
#   'runtime': 123.0,
#   'popularity': 1.8458990000000002},
#  '9263': {'title': 'Now and Then',
#   'budget': '12000000',
#   'vote_count': 91.0,
#   'vote_avg': 6.6,
#   'revenue': 27400000.0,
#   'genres': [' Comedy', ' Drama', ' Family'],
#   'runtime': 100.0,
#   'popularity': 8.681325},
#  '17015': {'title': 'Persuasion',
#   'budget': '0',
#   'vote_count': 36.0,
#   'vote_avg': 7.4,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 104.0,
#   'popularity': 2.228434},
#  '902': {'title': 'La Cité des Enfants Perdus',
#   'budget': '18000000',
#   'vote_count': 308.0,
#   'vote_avg': 7.6,
#   'revenue': 1738611.0,
#   'genres': [' Fantasy', ' Science Fiction', ' Adventure'],
#   'runtime': 108.0,
#   'popularity': 9.822422999999999},
#  '37557': {'title': '摇啊摇，摇到外婆桥',
#   'budget': '0',
#   'vote_count': 17.0,
#   'vote_avg': 6.5,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Crime'],
#   'runtime': 108.0,
#   'popularity': 1.1009149999999999},
#  '9909': {'title': 'Dangerous Minds',
#   'budget': '0',
#   'vote_count': 249.0,
#   'vote_avg': 6.4,
#   'revenue': 180000000.0,
#   'genres': [' Drama', ' Crime'],
#   'runtime': 99.0,
#   'popularity': 9.481338000000001},
#  '63': {'title': 'Twelve Monkeys',
#   'budget': '29500000',
#   'vote_count': 2470.0,
#   'vote_avg': 7.4,
#   'revenue': 168840000.0,
#   'genres': [' Science Fiction', ' Thriller', ' Mystery'],
#   'runtime': 129.0,
#   'popularity': 12.297305},
#  '78802': {'title': 'Guillaumet, les ailes du courage',
#   'budget': '0',
#   'vote_count': 4.0,
#   'vote_avg': 6.8,
#   'revenue': 0.0,
#   'genres': [' Romance', ' Adventure'],
#   'runtime': 50.0,
#   'popularity': 0.745542},
#  '9598': {'title': 'Babe',
#   'budget': '30000000',
#   'vote_count': 756.0,
#   'vote_avg': 6.0,
#   'revenue': 254134910.0,
#   'genres': [' Fantasy', ' Drama', ' Comedy', ' Family'],
#   'runtime': 89.0,
#   'popularity': 14.404764000000002},
#  '47018': {'title': 'Carrington',
#   'budget': '0',
#   'vote_count': 16.0,
#   'vote_avg': 6.4,
#   'revenue': 0.0,
#   'genres': [' History', ' Drama', ' Romance'],
#   'runtime': 121.0,
#   'popularity': 1.4933610000000002},
#  '687': {'title': 'Dead Man Walking',
#   'budget': '11000000',
#   'vote_count': 350.0,
#   'vote_avg': 7.3,
#   'revenue': 39363635.0,
#   'genres': [' Drama'],
#   'runtime': 122.0,
#   'popularity': 6.891317},
#  '139405': {'title': 'Across the Sea of Time',
#   'budget': '0',
#   'vote_count': 2.0,
#   'vote_avg': 3.5,
#   'revenue': 0.0,
#   'genres': [' Adventure', ' History', ' Drama', ' Family'],
#   'runtime': 51.0,
#   'popularity': 0.114469},
#  '33689': {'title': 'It Takes Two',
#   'budget': '0',
#   'vote_count': 149.0,
#   'vote_avg': 6.1,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Family', ' Romance'],
#   'runtime': 101.0,
#   'popularity': 7.777735000000001},
#  '9603': {'title': 'Clueless',
#   'budget': '12000000',
#   'vote_count': 828.0,
#   'vote_avg': 6.9,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Drama', ' Romance'],
#   'runtime': 97.0,
#   'popularity': 9.882383},
#  '34615': {'title': 'Cry, the Beloved Country',
#   'budget': '0',
#   'vote_count': 13.0,
#   'vote_avg': 6.7,
#   'revenue': 676525.0,
#   'genres': [' Drama'],
#   'runtime': 106.0,
#   'popularity': 0.894647},
#  '31174': {'title': 'Richard III',
#   'budget': '0',
#   'vote_count': 50.0,
#   'vote_avg': 6.9,
#   'revenue': 0.0,
#   'genres': [' Drama', ' War'],
#   'runtime': 104.0,
#   'popularity': 4.561387},
#  '11443': {'title': 'Dead Presidents',
#   'budget': '10000000',
#   'vote_count': 80.0,
#   'vote_avg': 6.6,
#   'revenue': 0.0,
#   'genres': [' Action', ' Crime', ' Drama', ' History'],
#   'runtime': 119.0,
#   'popularity': 9.87957},
#  '35196': {'title': 'Restoration',
#   'budget': '19000000',
#   'vote_count': 30.0,
#   'vote_avg': 6.3,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 117.0,
#   'popularity': 10.979269},
#  '9312': {'title': 'Mortal Kombat',
#   'budget': '18000000',
#   'vote_count': 452.0,
#   'vote_avg': 5.4,
#   'revenue': 122195920.0,
#   'genres': [' Action', ' Fantasy'],
#   'runtime': 101.0,
#   'popularity': 10.870138},
#  '577': {'title': 'To Die For',
#   'budget': '20000000',
#   'vote_count': 177.0,
#   'vote_avg': 6.7,
#   'revenue': 21284514.0,
#   'genres': [' Fantasy', ' Drama', ' Comedy', ' Thriller'],
#   'runtime': 106.0,
#   'popularity': 10.448481},
#  '11861': {'title': 'How To Make An American Quilt',
#   'budget': '10000000',
#   'vote_count': 38.0,
#   'vote_avg': 6.5,
#   'revenue': 23574130.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 116.0,
#   'popularity': 4.485958},
#  '807': {'title': 'Se7en',
#   'budget': '33000000',
#   'vote_count': 5915.0,
#   'vote_avg': 8.1,
#   'revenue': 327311859.0,
#   'genres': [' Crime', ' Mystery', ' Thriller'],
#   'runtime': 127.0,
#   'popularity': 18.45743},
#  '10530': {'title': 'Pocahontas',
#   'budget': '55000000',
#   'vote_count': 1509.0,
#   'vote_avg': 6.7,
#   'revenue': 346079773.0,
#   'genres': [' Adventure', ' Animation', ' Drama', ' Family'],
#   'runtime': 81.0,
#   'popularity': 13.280069000000001},
#  '8391': {'title': 'When Night Is Falling',
#   'budget': '0',
#   'vote_count': 10.0,
#   'vote_avg': 5.9,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 96.0,
#   'popularity': 3.302524},
#  '629': {'title': 'The Usual Suspects',
#   'budget': '6000000',
#   'vote_count': 3334.0,
#   'vote_avg': 8.1,
#   'revenue': 23341568.0,
#   'genres': [' Drama', ' Crime', ' Thriller'],
#   'runtime': 106.0,
#   'popularity': 16.302466},
#  '117164': {'title': 'Guardian Angel',
#   'budget': '0',
#   'vote_count': 3.0,
#   'vote_avg': 6.3,
#   'revenue': 0.0,
#   'genres': [' Action', ' Thriller', ' Drama'],
#   'runtime': 93.0,
#   'popularity': 0.595949},
#  '11448': {'title': 'Mighty Aphrodite',
#   'budget': '15000000',
#   'vote_count': 145.0,
#   'vote_avg': 6.7,
#   'revenue': 6700000.0,
#   'genres': [' Comedy', ' Romance'],
#   'runtime': 95.0,
#   'popularity': 15.899134},
#  '49133': {'title': 'Lamerica',
#   'budget': '0',
#   'vote_count': 11.0,
#   'vote_avg': 7.7,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Foreign'],
#   'runtime': 116.0,
#   'popularity': 1.361286},
#  '26441': {'title': 'The Big Green',
#   'budget': '0',
#   'vote_count': 41.0,
#   'vote_avg': 5.2,
#   'revenue': 0.0,
#   'genres': [' Action', ' Adventure', ' Comedy', ' Family'],
#   'runtime': 100.0,
#   'popularity': 5.9827639999999995},
#  '97406': {'title': 'Georgia',
#   'budget': '0',
#   'vote_count': 15.0,
#   'vote_avg': 6.1,
#   'revenue': 0.0,
#   'genres': [' Drama'],
#   'runtime': 115.0,
#   'popularity': 4.093443},
#  '124057': {'title': 'Kids of the Round Table',
#   'budget': '0',
#   'vote_count': 1.0,
#   'vote_avg': 3.0,
#   'revenue': 0.0,
#   'genres': [],
#   'runtime': 89.0,
#   'popularity': 0.307075},
#  '9089': {'title': 'Home for the Holidays',
#   'budget': '0',
#   'vote_count': 39.0,
#   'vote_avg': 6.3,
#   'revenue': 17519169.0,
#   'genres': [' Comedy', ' Drama', ' Romance'],
#   'runtime': 103.0,
#   'popularity': 8.416802},
#  '11010': {'title': 'Il postino',
#   'budget': '0',
#   'vote_count': 181.0,
#   'vote_avg': 7.6,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Drama', ' Romance'],
#   'runtime': 108.0,
#   'popularity': 10.168436999999999},
#  '99040': {'title': 'Le confessionnal',
#   'budget': '0',
#   'vote_count': 2.0,
#   'vote_avg': 6.5,
#   'revenue': 0.0,
#   'genres': [' Thriller', ' Drama', ' Mystery'],
#   'runtime': 100.0,
#   'popularity': 0.12078900000000001},
#  '11359': {'title': 'The Indian in the Cupboard',
#   'budget': '45000000',
#   'vote_count': 136.0,
#   'vote_avg': 5.9,
#   'revenue': 0.0,
#   'genres': [' Adventure', ' Family', ' Fantasy'],
#   'runtime': 96.0,
#   'popularity': 10.673296},
#  '17182': {'title': 'Eye for an Eye',
#   'budget': '20000000',
#   'vote_count': 65.0,
#   'vote_avg': 5.8,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Thriller'],
#   'runtime': 101.0,
#   'popularity': 4.733526},
#  '2054': {'title': "Mr. Holland's Opus",
#   'budget': '0',
#   'vote_count': 115.0,
#   'vote_avg': 6.9,
#   'revenue': 106269971.0,
#   'genres': [' Music', ' Drama', ' Family'],
#   'runtime': 137.0,
#   'popularity': 7.137117},
#  '10607': {'title': "Don't Be a Menace to South Central While Drinking Your Juice in the Hood",
#   'budget': '0',
#   'vote_count': 192.0,
#   'vote_avg': 6.2,
#   'revenue': 0.0,
#   'genres': [' Comedy'],
#   'runtime': 89.0,
#   'popularity': 11.700115},
#  '19760': {'title': 'Two If by Sea',
#   'budget': '0',
#   'vote_count': 14.0,
#   'vote_avg': 4.5,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Romance'],
#   'runtime': 96.0,
#   'popularity': 2.174487},
#  '9536': {'title': 'Bio-Dome',
#   'budget': '15000000',
#   'vote_count': 110.0,
#   'vote_avg': 4.4,
#   'revenue': 0.0,
#   'genres': [' Comedy'],
#   'runtime': 88.0,
#   'popularity': 6.387469},
#  '11525': {'title': 'Lawnmower Man 2: Beyond Cyberspace',
#   'budget': '0',
#   'vote_count': 32.0,
#   'vote_avg': 2.8,
#   'revenue': 2409225.0,
#   'genres': [' Action', ' Science Fiction'],
#   'runtime': 92.0,
#   'popularity': 2.49535},
#  '40628': {'title': 'Two Bits',
#   'budget': '0',
#   'vote_count': 11.0,
#   'vote_avg': 5.4,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Family'],
#   'runtime': 85.0,
#   'popularity': 4.046208},
#  '4482': {'title': 'Gazon maudit',
#   'budget': '0',
#   'vote_count': 43.0,
#   'vote_avg': 6.0,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Romance'],
#   'runtime': 95.0,
#   'popularity': 2.518051},
#  '10634': {'title': 'Friday',
#   'budget': '3500000',
#   'vote_count': 513.0,
#   'vote_avg': 7.0,
#   'revenue': 28215918.0,
#   'genres': [' Comedy'],
#   'runtime': 91.0,
#   'popularity': 14.56965},
#  '755': {'title': 'From Dusk Till Dawn',
#   'budget': '19000000',
#   'vote_count': 1644.0,
#   'vote_avg': 6.9,
#   'revenue': 25836616.0,
#   'genres': [' Horror', ' Action', ' Thriller', ' Crime'],
#   'runtime': 108.0,
#   'popularity': 15.339153},
#  '11859': {'title': 'Fair Game',
#   'budget': '50000000',
#   'vote_count': 54.0,
#   'vote_avg': 4.1,
#   'revenue': 11534477.0,
#   'genres': [' Action', ' Thriller', ' Romance'],
#   'runtime': 91.0,
#   'popularity': 5.912223},
#  '28387': {'title': 'Kicking and Screaming',
#   'budget': '0',
#   'vote_count': 36.0,
#   'vote_avg': 7.0,
#   'revenue': 718490.0,
#   'genres': [' Comedy', ' Drama', ' Romance'],
#   'runtime': 96.0,
#   'popularity': 3.3672760000000004},
#  '48750': {'title': 'Les misérables',
#   'budget': '0',
#   'vote_count': 8.0,
#   'vote_avg': 6.6,
#   'revenue': 0.0,
#   'genres': [' Drama', ' History'],
#   'runtime': 175.0,
#   'popularity': 1.4794459999999998},
#  '20927': {'title': 'Bed of Roses',
#   'budget': '0',
#   'vote_count': 27.0,
#   'vote_avg': 5.1,
#   'revenue': 19030691.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 87.0,
#   'popularity': 10.412194},
#  '36929': {'title': 'Big Bully',
#   'budget': '15000000',
#   'vote_count': 16.0,
#   'vote_avg': 3.9,
#   'revenue': 2042530.0,
#   'genres': [' Comedy', ' Family'],
#   'runtime': 90.0,
#   'popularity': 2.936443},
#  '9102': {'title': 'Screamers',
#   'budget': '20000000',
#   'vote_count': 154.0,
#   'vote_avg': 6.1,
#   'revenue': 5781885.0,
#   'genres': [' Horror', ' Science Fiction'],
#   'runtime': 108.0,
#   'popularity': 12.758848},
#  '124626': {'title': 'Nico Icon',
#   'budget': '0',
#   'vote_count': 3.0,
#   'vote_avg': 7.3,
#   'revenue': 0.0,
#   'genres': [' Documentary'],
#   'runtime': 70.0,
#   'popularity': 0.133893},
#  '27526': {'title': 'The Crossing Guard',
#   'budget': '0',
#   'vote_count': 74.0,
#   'vote_avg': 6.1,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Thriller'],
#   'runtime': 111.0,
#   'popularity': 5.756462},
#  '9623': {'title': 'The Juror',
#   'budget': '44000000',
#   'vote_count': 91.0,
#   'vote_avg': 5.5,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Thriller'],
#   'runtime': 118.0,
#   'popularity': 6.010579},
#  '46785': {'title': 'بادکنک سفید',
#   'budget': '0',
#   'vote_count': 20.0,
#   'vote_avg': 7.5,
#   'revenue': 0.0,
#   'genres': [' Family', ' Drama'],
#   'runtime': 85.0,
#   'popularity': 1.196256},
#  '400': {'title': "Things to Do in Denver When You're Dead",
#   'budget': '8000000',
#   'vote_count': 87.0,
#   'vote_avg': 6.7,
#   'revenue': 529766.0,
#   'genres': [' Drama', ' Crime'],
#   'runtime': 116.0,
#   'popularity': 4.486179},
#  '880': {'title': 'Antonia',
#   'budget': '900000',
#   'vote_count': 26.0,
#   'vote_avg': 7.2,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Comedy'],
#   'runtime': 102.0,
#   'popularity': 2.030174},
#  '146599': {'title': 'Once Upon a Time... When We Were Colored',
#   'budget': '0',
#   'vote_count': 2.0,
#   'vote_avg': 4.5,
#   'revenue': 0.0,
#   'genres': [' Romance', ' Drama'],
#   'runtime': 115.0,
#   'popularity': 0.252287},
#  '188588': {'title': 'Last Summer in the Hamptons',
#   'budget': '0',
#   'vote_count': 0.0,
#   'vote_avg': 0.0,
#   'revenue': 0.0,
#   'genres': [],
#   'runtime': 108.0,
#   'popularity': 0.531159},
#  '8447': {'title': 'Angels and Insects',
#   'budget': '0',
#   'vote_count': 17.0,
#   'vote_avg': 6.3,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 118.0,
#   'popularity': 2.1516599999999997},
#  '10534': {'title': 'White Squall',
#   'budget': '38000000',
#   'vote_count': 86.0,
#   'vote_avg': 6.3,
#   'revenue': 10300000.0,
#   'genres': [' Action', ' Drama'],
#   'runtime': 129.0,
#   'popularity': 9.568603999999999},
#  '17414': {'title': 'Dunston Checks In',
#   'budget': '16000000',
#   'vote_count': 59.0,
#   'vote_avg': 5.1,
#   'revenue': 0.0,
#   'genres': [' Adventure', ' Comedy', ' Family'],
#   'runtime': 88.0,
#   'popularity': 4.814825},
#  '13997': {'title': 'Black Sheep',
#   'budget': '0',
#   'vote_count': 124.0,
#   'vote_avg': 6.0,
#   'revenue': 32.0,
#   'genres': [' Comedy'],
#   'runtime': 87.0,
#   'popularity': 8.963037},
#  '2086': {'title': 'Nick of Time',
#   'budget': '8169363',
#   'vote_count': 190.0,
#   'vote_avg': 6.1,
#   'revenue': 8175346.0,
#   'genres': [' Crime', ' Drama', ' Thriller'],
#   'runtime': 90.0,
#   'popularity': 6.848591000000001},
#  '61548': {'title': 'The Journey of August King',
#   'budget': '0',
#   'vote_count': 3.0,
#   'vote_avg': 6.7,
#   'revenue': 0.0,
#   'genres': [' Drama'],
#   'runtime': 91.0,
#   'popularity': 0.41142399999999996},
#  '9095': {'title': 'Mary Reilly',
#   'budget': '47000000',
#   'vote_count': 77.0,
#   'vote_avg': 5.7,
#   'revenue': 12379402.0,
#   'genres': [' Drama', ' Horror', ' Thriller', ' Romance'],
#   'runtime': 104.0,
#   'popularity': 12.866139},
#  '12158': {'title': 'Vampire in Brooklyn',
#   'budget': '14000000',
#   'vote_count': 113.0,
#   'vote_avg': 4.5,
#   'revenue': 19800000.0,
#   'genres': [' Comedy', ' Horror', ' Romance'],
#   'runtime': 100.0,
#   'popularity': 9.071127},
#  '9283': {'title': 'Beautiful Girls',
#   'budget': '0',
#   'vote_count': 103.0,
#   'vote_avg': 6.6,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Drama', ' Romance'],
#   'runtime': 112.0,
#   'popularity': 4.670562},
#  '9208': {'title': 'Broken Arrow',
#   'budget': '50000000',
#   'vote_count': 459.0,
#   'vote_avg': 5.7,
#   'revenue': 150270147.0,
#   'genres': [' Action', ' Adventure', ' Drama', ' Thriller'],
#   'runtime': 108.0,
#   'popularity': 14.957626000000001},
#  '40154': {'title': "A Midwinter's Tale",
#   'budget': '0',
#   'vote_count': 6.0,
#   'vote_avg': 7.5,
#   'revenue': 0.0,
#   'genres': [' Comedy'],
#   'runtime': 99.0,
#   'popularity': 0.5133909999999999},
#  '406': {'title': 'La Haine',
#   'budget': '3000000',
#   'vote_count': 695.0,
#   'vote_avg': 7.9,
#   'revenue': 0.0,
#   'genres': [' Drama'],
#   'runtime': 98.0,
#   'popularity': 12.108196000000001},
#  '45549': {'title': 'Shopping',
#   'budget': '0',
#   'vote_count': 13.0,
#   'vote_avg': 5.6,
#   'revenue': 0.0,
#   'genres': [' Action',
#    ' Adventure',
#    ' Drama',
#    ' Science Fiction',
#    ' Thriller'],
#   'runtime': 105.0,
#   'popularity': 2.6576470000000003},
#  '63076': {'title': 'Heidi Fleiss: Hollywood Madam',
#   'budget': '0',
#   'vote_count': 4.0,
#   'vote_avg': 6.8,
#   'revenue': 0.0,
#   'genres': [' Documentary'],
#   'runtime': 106.0,
#   'popularity': 0.638211},
#  '11062': {'title': 'City Hall',
#   'budget': '0',
#   'vote_count': 67.0,
#   'vote_avg': 6.0,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Thriller'],
#   'runtime': 111.0,
#   'popularity': 4.8072230000000005},
#  '13685': {'title': 'Bottle Rocket',
#   'budget': '7000000',
#   'vote_count': 285.0,
#   'vote_avg': 6.8,
#   'revenue': 560069.0,
#   'genres': [' Comedy', ' Crime', ' Drama'],
#   'runtime': 91.0,
#   'popularity': 6.904831},
#  '47475': {'title': 'Mr. Wrong',
#   'budget': '0',
#   'vote_count': 16.0,
#   'vote_avg': 3.3,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Romance'],
#   'runtime': 96.0,
#   'popularity': 3.329264},
#  '2045': {'title': 'Unforgettable',
#   'budget': '18000000',
#   'vote_count': 22.0,
#   'vote_avg': 5.3,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Mystery', ' Science Fiction', ' Thriller'],
#   'runtime': 106.0,
#   'popularity': 2.464425},
#  '9614': {'title': 'Happy Gilmore',
#   'budget': '12000000',
#   'vote_count': 767.0,
#   'vote_avg': 6.5,
#   'revenue': 41205099.0,
#   'genres': [' Comedy'],
#   'runtime': 92.0,
#   'popularity': 9.592265},
#  '688': {'title': 'The Bridges of Madison County',
#   'budget': '24000000',
#   'vote_count': 397.0,
#   'vote_avg': 7.3,
#   'revenue': 182016617.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 135.0,
#   'popularity': 5.951077},
#  '11907': {'title': 'Keiner liebt mich',
#   'budget': '0',
#   'vote_count': 5.0,
#   'vote_avg': 5.1,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Comedy', ' Family'],
#   'runtime': 104.0,
#   'popularity': 1.015068},
#  '10874': {'title': 'Muppet Treasure Island',
#   'budget': '0',
#   'vote_count': 93.0,
#   'vote_avg': 6.5,
#   'revenue': 34327391.0,
#   'genres': [' Action', ' Comedy', ' Music', ' Family', ' Adventure'],
#   'runtime': 100.0,
#   'popularity': 6.902423},
#  '89333': {'title': 'Catwalk',
#   'budget': '0',
#   'vote_count': 2.0,
#   'vote_avg': 7.0,
#   'revenue': 0.0,
#   'genres': [' Documentary'],
#   'runtime': 95.0,
#   'popularity': 0.976707},
#  '96357': {'title': 'Headless Body in Topless Bar',
#   'budget': '0',
#   'vote_count': 0.0,
#   'vote_avg': 0.0,
#   'revenue': 0.0,
#   'genres': [' Crime'],
#   'runtime': 110.0,
#   'popularity': 0.0013460000000000002},
#  '197': {'title': 'Braveheart',
#   'budget': '72000000',
#   'vote_count': 3404.0,
#   'vote_avg': 7.7,
#   'revenue': 210000000.0,
#   'genres': [' Action', ' Drama', ' History', ' War'],
#   'runtime': 177.0,
#   'popularity': 20.755149},
#  '103': {'title': 'Taxi Driver',
#   'budget': '1300000',
#   'vote_count': 2632.0,
#   'vote_avg': 8.1,
#   'revenue': 28262574.0,
#   'genres': [' Crime', ' Drama'],
#   'runtime': 114.0,
#   'popularity': 14.092713},
#  '33542': {'title': '紅番區',
#   'budget': '7500000',
#   'vote_count': 245.0,
#   'vote_avg': 6.5,
#   'revenue': 32392047.0,
#   'genres': [' Crime', ' Action', ' Comedy', ' Thriller'],
#   'runtime': 91.0,
#   'popularity': 12.314278},
#  '43566': {'title': 'Before and After',
#   'budget': '35000000',
#   'vote_count': 37.0,
#   'vote_avg': 5.8,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Thriller'],
#   'runtime': 108.0,
#   'popularity': 2.938293},
#  '71754': {'title': "Margaret's Museum",
#   'budget': '0',
#   'vote_count': 2.0,
#   'vote_avg': 7.5,
#   'revenue': 0.0,
#   'genres': [' Drama'],
#   'runtime': 114.0,
#   'popularity': 0.372697},
#  '43612': {'title': 'Le Bonheur est dans le pré',
#   'budget': '13365000',
#   'vote_count': 23.0,
#   'vote_avg': 7.0,
#   'revenue': 0.0,
#   'genres': [' Comedy'],
#   'runtime': 106.0,
#   'popularity': 1.254885},
#  '51352': {'title': 'Anne Frank Remembered',
#   'budget': '0',
#   'vote_count': 4.0,
#   'vote_avg': 7.3,
#   'revenue': 1.0,
#   'genres': [' Documentary', ' Drama', ' Foreign'],
#   'runtime': 117.0,
#   'popularity': 0.243986},
#  '16934': {'title': "The Young Poisoner's Handbook",
#   'budget': '0',
#   'vote_count': 19.0,
#   'vote_avg': 6.9,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Crime', ' Drama'],
#   'runtime': 99.0,
#   'popularity': 6.178497},
#  '10324': {'title': 'If Lucy Fell',
#   'budget': '0',
#   'vote_count': 11.0,
#   'vote_avg': 5.4,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Romance'],
#   'runtime': 92.0,
#   'popularity': 2.891918},
#  '78406': {'title': 'Steal Big Steal Little',
#   'budget': '25000000',
#   'vote_count': 7.0,
#   'vote_avg': 5.1,
#   'revenue': 6278139.0,
#   'genres': [' Comedy', ' Drama'],
#   'runtime': 113.0,
#   'popularity': 1.522412},
#  '55731': {'title': 'Race the Sun',
#   'budget': '0',
#   'vote_count': 21.0,
#   'vote_avg': 5.2,
#   'revenue': 0.0,
#   'genres': [' Action', ' Adventure', ' Comedy', ' Drama', ' Family'],
#   'runtime': 100.0,
#   'popularity': 1.317878},
#  '32119': {'title': 'The Boys of St. Vincent',
#   'budget': '0',
#   'vote_count': 7.0,
#   'vote_avg': 7.0,
#   'revenue': 0.0,
#   'genres': [' Drama'],
#   'runtime': 90.0,
#   'popularity': 0.86539},
#  '11066': {'title': 'Boomerang',
#   'budget': '40000000',
#   'vote_count': 139.0,
#   'vote_avg': 5.4,
#   'revenue': 70100000.0,
#   'genres': [' Comedy', ' Romance'],
#   'runtime': 117.0,
#   'popularity': 6.506983},
#  '11104': {'title': '重慶森林',
#   'budget': '0',
#   'vote_count': 249.0,
#   'vote_avg': 7.9,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Comedy', ' Romance'],
#   'runtime': 102.0,
#   'popularity': 6.778979},
#  '37975': {'title': "L'uomo delle stelle",
#   'budget': '0',
#   'vote_count': 29.0,
#   'vote_avg': 6.8,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 113.0,
#   'popularity': 1.702639},
#  '2074': {'title': 'Flirting with Disaster',
#   'budget': '7000000',
#   'vote_count': 66.0,
#   'vote_avg': 6.3,
#   'revenue': 14702438.0,
#   'genres': [' Comedy', ' Romance'],
#   'runtime': 92.0,
#   'popularity': 5.579088},
#  '27793': {'title': 'The NeverEnding Story III',
#   'budget': '17000000',
#   'vote_count': 105.0,
#   'vote_avg': 4.4,
#   'revenue': 0.0,
#   'genres': [' Fantasy'],
#   'runtime': 95.0,
#   'popularity': 6.252377},
#  '44284': {'title': 'صمت القصور',
#   'budget': '0',
#   'vote_count': 3.0,
#   'vote_avg': 4.3,
#   'revenue': 0.0,
#   'genres': [' Drama'],
#   'runtime': 116.0,
#   'popularity': 0.406754},
#  '290157': {'title': "Jupiter's Wife",
#   'budget': '0',
#   'vote_count': 0.0,
#   'vote_avg': 0.0,
#   'revenue': 0.0,
#   'genres': [],
#   'runtime': 87.0,
#   'popularity': 0.001178},
#  '110972': {'title': 'Pie in the Sky',
#   'budget': '0',
#   'vote_count': 2.0,
#   'vote_avg': 7.0,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Romance'],
#   'runtime': 95.0,
#   'popularity': 0.699066},
#  '32622': {'title': 'Angela',
#   'budget': '0',
#   'vote_count': 9.0,
#   'vote_avg': 5.6,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Drama'],
#   'runtime': 99.0,
#   'popularity': 2.197439},
#  '73067': {'title': 'Frankie Starlight',
#   'budget': '0',
#   'vote_count': 4.0,
#   'vote_avg': 5.4,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Romance', ' War'],
#   'runtime': 101.0,
#   'popularity': 0.637554},
#  '11863': {'title': 'Jade',
#   'budget': '50000000',
#   'vote_count': 45.0,
#   'vote_avg': 5.1,
#   'revenue': 9851610.0,
#   'genres': [' Action', ' Thriller', ' Mystery', ' Romance'],
#   'runtime': 95.0,
#   'popularity': 11.418917},
#  '55475': {'title': 'Nueba Yol',
#   'budget': '0',
#   'vote_count': 1.0,
#   'vote_avg': 5.5,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Drama', ' Romance'],
#   'runtime': 102.0,
#   'popularity': 0.29102100000000003},
#  '124636': {'title': 'Sonic Outlaws',
#   'budget': '0',
#   'vote_count': 0.0,
#   'vote_avg': 0.0,
#   'revenue': 0.0,
#   'genres': [' Music', ' Documentary'],
#   'runtime': 87.0,
#   'popularity': 0.001838},
#  '9101': {'title': 'Down Periscope',
#   'budget': '0',
#   'vote_count': 110.0,
#   'vote_avg': 5.6,
#   'revenue': 0.0,
#   'genres': [' Comedy'],
#   'runtime': 92.0,
#   'popularity': 5.184977},
#  '123360': {'title': 'From the Journals of Jean Seberg',
#   'budget': '0',
#   'vote_count': 2.0,
#   'vote_avg': 6.5,
#   'revenue': 0.0,
#   'genres': [' Documentary'],
#   'runtime': 97.0,
#   'popularity': 0.276401},
#  '5757': {'title': 'Man of the Year',
#   'budget': '0',
#   'vote_count': 2.0,
#   'vote_avg': 3.8,
#   'revenue': 209935.0,
#   'genres': [' Comedy'],
#   'runtime': 86.0,
#   'popularity': 0.5404359999999999},
#  '39428': {'title': 'The Neon Bible',
#   'budget': '0',
#   'vote_count': 5.0,
#   'vote_avg': 7.2,
#   'revenue': 0.0,
#   'genres': [' Drama'],
#   'runtime': 91.0,
#   'popularity': 0.370342},
#  '124639': {'title': 'Target',
#   'budget': '0',
#   'vote_count': 0.0,
#   'vote_avg': 0.0,
#   'revenue': 0.0,
#   'genres': [],
#   'runtime': 122.0,
#   'popularity': 0.0012050000000000001},
#  '9302': {'title': 'Up Close & Personal',
#   'budget': '60000000',
#   'vote_count': 51.0,
#   'vote_avg': 5.9,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 119.0,
#   'popularity': 3.4027489999999996},
#  '11000': {'title': 'The Birdcage',
#   'budget': '31000000',
#   'vote_count': 303.0,
#   'vote_avg': 6.7,
#   'revenue': 185260553.0,
#   'genres': [' Comedy'],
#   'runtime': 117.0,
#   'popularity': 6.499680000000001},
#  '249882': {'title': 'Gospa',
#   'budget': '0',
#   'vote_count': 2.0,
#   'vote_avg': 7.0,
#   'revenue': 0.0,
#   'genres': [' Drama'],
#   'runtime': 125.0,
#   'popularity': 0.9185040000000001},
#  '16388': {'title': 'The Brothers McMullen',
#   'budget': '0',
#   'vote_count': 23.0,
#   'vote_avg': 6.3,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Drama', ' Romance'],
#   'runtime': 98.0,
#   'popularity': 2.039196},
#  '9737': {'title': 'Bad Boys',
#   'budget': '19000000',
#   'vote_count': 1729.0,
#   'vote_avg': 6.5,
#   'revenue': 141407024.0,
#   'genres': [' Action', ' Comedy', ' Crime', ' Thriller'],
#   'runtime': 118.0,
#   'popularity': 9.262184},
#  '30765': {'title': 'The Amazing Panda Adventure',
#   'budget': '0',
#   'vote_count': 31.0,
#   'vote_avg': 5.0,
#   'revenue': 0.0,
#   'genres': [' Action', ' Adventure', ' Drama', ' Family'],
#   'runtime': 81.0,
#   'popularity': 2.375865},
#  '10474': {'title': 'The Basketball Diaries',
#   'budget': '0',
#   'vote_count': 472.0,
#   'vote_avg': 7.2,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Crime'],
#   'runtime': 102.0,
#   'popularity': 7.415144000000001},
#  '22279': {'title': 'An Awfully Big Adventure',
#   'budget': '4000000',
#   'vote_count': 11.0,
#   'vote_avg': 6.0,
#   'revenue': 851545.0,
#   'genres': [' Romance', ' Drama', ' Comedy'],
#   'runtime': 113.0,
#   'popularity': 0.922958},
#  '30157': {'title': 'Amateur',
#   'budget': '0',
#   'vote_count': 21.0,
#   'vote_avg': 6.5,
#   'revenue': 0.0,
#   'genres': [' Crime', ' Comedy', ' Drama', ' Thriller'],
#   'runtime': 105.0,
#   'popularity': 1.7590119999999998},
#  '568': {'title': 'Apollo 13',
#   'budget': '52000000',
#   'vote_count': 1637.0,
#   'vote_avg': 7.3,
#   'revenue': 355237933.0,
#   'genres': [' Drama'],
#   'runtime': 140.0,
#   'popularity': 18.761467},
#  '11780': {'title': 'Rob Roy',
#   'budget': '28000000',
#   'vote_count': 151.0,
#   'vote_avg': 6.5,
#   'revenue': 31596911.0,
#   'genres': [' Adventure'],
#   'runtime': 139.0,
#   'popularity': 10.193549},
#  '34996': {'title': 'The Addiction',
#   'budget': '0',
#   'vote_count': 46.0,
#   'vote_avg': 6.4,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Horror'],
#   'runtime': 82.0,
#   'popularity': 3.137285},
#  '414': {'title': 'Batman Forever',
#   'budget': '100000000',
#   'vote_count': 1529.0,
#   'vote_avg': 5.2,
#   'revenue': 336529144.0,
#   'genres': [' Action', ' Crime', ' Fantasy'],
#   'runtime': 121.0,
#   'popularity': 13.321354000000001},
#  '649': {'title': 'Belle de jour',
#   'budget': '0',
#   'vote_count': 163.0,
#   'vote_avg': 7.3,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 101.0,
#   'popularity': 10.142662},
#  '1873': {'title': 'Beyond Rangoon',
#   'budget': '0',
#   'vote_count': 21.0,
#   'vote_avg': 6.4,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Thriller'],
#   'runtime': 100.0,
#   'popularity': 2.04189},
#  '5894': {'title': 'Blue in the Face',
#   'budget': '2000000',
#   'vote_count': 28.0,
#   'vote_avg': 6.8,
#   'revenue': 1275000.0,
#   'genres': [' Comedy'],
#   'runtime': 83.0,
#   'popularity': 11.528147},
#  '1775': {'title': 'Canadian Bacon',
#   'budget': '11000000',
#   'vote_count': 57.0,
#   'vote_avg': 5.9,
#   'revenue': 178104.0,
#   'genres': [' Action', ' Comedy'],
#   'runtime': 91.0,
#   'popularity': 5.391556},
#  '8839': {'title': 'Casper',
#   'budget': '50000000',
#   'vote_count': 1045.0,
#   'vote_avg': 6.0,
#   'revenue': 287928194.0,
#   'genres': [' Fantasy', ' Comedy', ' Family'],
#   'runtime': 100.0,
#   'popularity': 12.812539},
#  '20649': {'title': 'Clockers',
#   'budget': '25000000',
#   'vote_count': 69.0,
#   'vote_avg': 6.8,
#   'revenue': 13071518.0,
#   'genres': [' Mystery', ' Crime', ' Drama'],
#   'runtime': 128.0,
#   'popularity': 4.558992},
#  '10329': {'title': 'Congo',
#   'budget': '50000000',
#   'vote_count': 214.0,
#   'vote_avg': 5.0,
#   'revenue': 152022101.0,
#   'genres': [' Action',
#    ' Adventure',
#    ' Drama',
#    ' Mystery',
#    ' Science Fiction',
#    ' Thriller'],
#   'runtime': 109.0,
#   'popularity': 7.260574},
#  '8963': {'title': 'Crimson Tide',
#   'budget': '53000000',
#   'vote_count': 508.0,
#   'vote_avg': 7.0,
#   'revenue': 157387195.0,
#   'genres': [' Action', ' Thriller', ' Drama'],
#   'runtime': 116.0,
#   'popularity': 8.657364999999999},
#  '26564': {'title': 'Crumb',
#   'budget': '0',
#   'vote_count': 71.0,
#   'vote_avg': 7.6,
#   'revenue': 3174695.0,
#   'genres': [' Documentary'],
#   'runtime': 119.0,
#   'popularity': 3.6203879999999997},
#  '8068': {'title': 'Desperado',
#   'budget': '7000000',
#   'vote_count': 898.0,
#   'vote_avg': 6.8,
#   'revenue': 25405445.0,
#   'genres': [' Thriller', ' Action', ' Crime'],
#   'runtime': 104.0,
#   'popularity': 6.950458},
#  '8512': {'title': 'Devil in a Blue Dress',
#   'budget': '27000000',
#   'vote_count': 88.0,
#   'vote_avg': 6.3,
#   'revenue': 16140822.0,
#   'genres': [' Drama', ' Mystery', ' Thriller'],
#   'runtime': 102.0,
#   'popularity': 4.646132},
#  '1572': {'title': 'Die Hard: With a Vengeance',
#   'budget': '90000000',
#   'vote_count': 2094.0,
#   'vote_avg': 6.9,
#   'revenue': 366101666.0,
#   'genres': [' Action', ' Thriller'],
#   'runtime': 128.0,
#   'popularity': 15.138855},
#  '13552': {'title': 'The Doom Generation',
#   'budget': '0',
#   'vote_count': 57.0,
#   'vote_avg': 5.6,
#   'revenue': 0.0,
#   'genres': [' Action', ' Comedy', ' Crime', ' Drama'],
#   'runtime': 80.0,
#   'popularity': 7.120806},
#  '259209': {'title': 'Feast of July',
#   'budget': '0',
#   'vote_count': 0.0,
#   'vote_avg': 0.0,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Crime'],
#   'runtime': 116.0,
#   'popularity': 0.523575},
#  '6520': {'title': 'First Knight',
#   'budget': '55000000',
#   'vote_count': 319.0,
#   'vote_avg': 5.9,
#   'revenue': 127600435.0,
#   'genres': [' Action', ' Adventure', ' Drama', ' Romance'],
#   'runtime': 134.0,
#   'popularity': 15.178338},
#  '9073': {'title': 'Free Willy 2 - The Adventure Home',
#   'budget': '0',
#   'vote_count': 130.0,
#   'vote_avg': 5.5,
#   'revenue': 0.0,
#   'genres': [' Adventure'],
#   'runtime': 95.0,
#   'popularity': 7.575098},
#  '10428': {'title': 'Hackers',
#   'budget': '20000000',
#   'vote_count': 406.0,
#   'vote_avg': 6.2,
#   'revenue': 7563728.0,
#   'genres': [' Action', ' Crime', ' Thriller', ' Drama'],
#   'runtime': 107.0,
#   'popularity': 14.810519000000001},
#  '17447': {'title': 'Jeffrey',
#   'budget': '0',
#   'vote_count': 19.0,
#   'vote_avg': 6.5,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Drama', ' Romance'],
#   'runtime': 92.0,
#   'popularity': 3.196456},
#  '9886': {'title': 'Johnny Mnemonic',
#   'budget': '25000000',
#   'vote_count': 380.0,
#   'vote_avg': 5.5,
#   'revenue': 19075720.0,
#   'genres': [' Adventure',
#    ' Action',
#    ' Drama',
#    ' Science Fiction',
#    ' Thriller'],
#   'runtime': 97.0,
#   'popularity': 11.715867999999999},
#  '9482': {'title': 'Judge Dredd',
#   'budget': '90000000',
#   'vote_count': 643.0,
#   'vote_avg': 5.4,
#   'revenue': 113493481.0,
#   'genres': [' Science Fiction'],
#   'runtime': 96.0,
#   'popularity': 8.184814999999999},
#  '19326': {'title': 'Jury Duty',
#   'budget': '0',
#   'vote_count': 34.0,
#   'vote_avg': 4.0,
#   'revenue': 17014653.0,
#   'genres': [' Comedy', ' Drama'],
#   'runtime': 88.0,
#   'popularity': 3.676921},
#  '9344': {'title': 'Kids',
#   'budget': '1500000',
#   'vote_count': 280.0,
#   'vote_avg': 6.8,
#   'revenue': 7412216.0,
#   'genres': [' Drama', ' Crime'],
#   'runtime': 91.0,
#   'popularity': 4.877872},
#  '9071': {'title': 'Living in Oblivion',
#   'budget': '500000',
#   'vote_count': 64.0,
#   'vote_avg': 7.2,
#   'revenue': 1148752.0,
#   'genres': [' Drama', ' Comedy'],
#   'runtime': 89.0,
#   'popularity': 10.058328999999999},
#  '8973': {'title': 'Lord of Illusions',
#   'budget': '0',
#   'vote_count': 87.0,
#   'vote_avg': 5.9,
#   'revenue': 0.0,
#   'genres': [' Mystery', ' Horror', ' Thriller'],
#   'runtime': 119.0,
#   'popularity': 4.102409},
#  '15730': {'title': 'Love & Human Remains',
#   'budget': '0',
#   'vote_count': 7.0,
#   'vote_avg': 7.0,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Drama'],
#   'runtime': 100.0,
#   'popularity': 0.354014},
#  '47608': {'title': 'Mad Love',
#   'budget': '0',
#   'vote_count': 27.0,
#   'vote_avg': 5.5,
#   'revenue': 15453274.0,
#   'genres': [' Drama', ' Family', ' Romance'],
#   'runtime': 95.0,
#   'popularity': 2.624771},
#  '2293': {'title': 'Mallrats',
#   'budget': '6000000',
#   'vote_count': 400.0,
#   'vote_avg': 6.8,
#   'revenue': 2122561.0,
#   'genres': [' Romance', ' Comedy'],
#   'runtime': 94.0,
#   'popularity': 8.255469999999999},
#  '9070': {'title': 'Mighty Morphin Power Rangers: The Movie',
#   'budget': '15000000',
#   'vote_count': 153.0,
#   'vote_avg': 5.2,
#   'revenue': 66000000.0,
#   'genres': [' Action',
#    ' Adventure',
#    ' Science Fiction',
#    ' Family',
#    ' Fantasy'],
#   'runtime': 92.0,
#   'popularity': 7.024227000000001},
#  '68274': {'title': 'Moonlight and Valentino',
#   'budget': '0',
#   'vote_count': 10.0,
#   'vote_avg': 5.6,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Drama', ' Romance'],
#   'runtime': 100.0,
#   'popularity': 1.01115},
#  '48787': {'title': 'Mute Witness',
#   'budget': '2',
#   'vote_count': 36.0,
#   'vote_avg': 6.4,
#   'revenue': 1.0,
#   'genres': [' Thriller', ' Foreign'],
#   'runtime': 95.0,
#   'popularity': 2.466066},
#  '34574': {'title': 'Nadja',
#   'budget': '0',
#   'vote_count': 12.0,
#   'vote_avg': 5.9,
#   'revenue': 0.0,
#   'genres': [' Horror', ' Thriller'],
#   'runtime': 93.0,
#   'popularity': 7.720056},
#  '1642': {'title': 'The Net',
#   'budget': '22000000',
#   'vote_count': 359.0,
#   'vote_avg': 5.6,
#   'revenue': 110627965.0,
#   'genres': [' Crime', ' Drama', ' Mystery', ' Thriller', ' Action'],
#   'runtime': 114.0,
#   'popularity': 13.304342000000002},
#  '11472': {'title': 'Nine Months',
#   'budget': '0',
#   'vote_count': 171.0,
#   'vote_avg': 5.5,
#   'revenue': 69660733.0,
#   'genres': [' Comedy'],
#   'runtime': 103.0,
#   'popularity': 8.482834},
#  '36196': {'title': 'Party Girl',
#   'budget': '150000',
#   'vote_count': 14.0,
#   'vote_avg': 5.8,
#   'revenue': 472370.0,
#   'genres': [' Comedy'],
#   'runtime': 94.0,
#   'popularity': 1.165039},
#  '11980': {'title': 'The Prophecy',
#   'budget': '8',
#   'vote_count': 139.0,
#   'vote_avg': 6.4,
#   'revenue': 16.0,
#   'genres': [' Fantasy', ' Horror', ' Thriller'],
#   'runtime': 98.0,
#   'popularity': 10.187623},
#  '58372': {'title': 'Reckless',
#   'budget': '0',
#   'vote_count': 1.0,
#   'vote_avg': 10.0,
#   'revenue': 0.0,
#   'genres': [' Fantasy', ' Comedy', ' Drama'],
#   'runtime': 91.0,
#   'popularity': 0.11971300000000001},
#  '32646': {'title': 'Safe',
#   'budget': '0',
#   'vote_count': 62.0,
#   'vote_avg': 7.2,
#   'revenue': 0.0,
#   'genres': [' Drama'],
#   'runtime': 119.0,
#   'popularity': 8.180047},
#  '10533': {'title': 'The Scarlet Letter',
#   'budget': '50000000',
#   'vote_count': 111.0,
#   'vote_avg': 5.5,
#   'revenue': 10382407.0,
#   'genres': [' Drama', ' History', ' Romance'],
#   'runtime': 135.0,
#   'popularity': 6.752119},
#  '56088': {'title': 'The Show',
#   'budget': '0',
#   'vote_count': 2.0,
#   'vote_avg': 5.3,
#   'revenue': 0.0,
#   'genres': [' Documentary'],
#   'runtime': 93.0,
#   'popularity': 0.15959600000000002},
#  '10802': {'title': 'Showgirls',
#   'budget': '45000000',
#   'vote_count': 261.0,
#   'vote_avg': 4.9,
#   'revenue': 20350754.0,
#   'genres': [' Drama'],
#   'runtime': 128.0,
#   'popularity': 17.502375},
#  '10149': {'title': 'Smoke',
#   'budget': '7000000',
#   'vote_count': 115.0,
#   'vote_avg': 7.2,
#   'revenue': 8349430.0,
#   'genres': [' Comedy', ' Drama'],
#   'runtime': 112.0,
#   'popularity': 5.5529459999999995},
#  '18402': {'title': 'Something to Talk About',
#   'budget': '0',
#   'vote_count': 60.0,
#   'vote_avg': 5.7,
#   'revenue': 50892160.0,
#   'genres': [' Comedy'],
#   'runtime': 106.0,
#   'popularity': 3.743212},
#  '9348': {'title': 'Species',
#   'budget': '35000000',
#   'vote_count': 457.0,
#   'vote_avg': 5.5,
#   'revenue': 113374103.0,
#   'genres': [' Science Fiction', ' Horror', ' Action'],
#   'runtime': 108.0,
#   'popularity': 13.492845},
#  '139408': {'title': 'The Stars Fell on Henrietta',
#   'budget': '0',
#   'vote_count': 6.0,
#   'vote_avg': 6.6,
#   'revenue': 0.0,
#   'genres': [' Drama'],
#   'runtime': 109.0,
#   'popularity': 0.913522},
#  '281': {'title': 'Strange Days',
#   'budget': '42000000',
#   'vote_count': 334.0,
#   'vote_avg': 6.8,
#   'revenue': 7959291.0,
#   'genres': [' Crime', ' Drama', ' Science Fiction', ' Thriller'],
#   'runtime': 145.0,
#   'popularity': 11.223055},
#  '5967': {'title': 'Les parapluies de Cherbourg',
#   'budget': '0',
#   'vote_count': 119.0,
#   'vote_avg': 7.6,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 91.0,
#   'popularity': 8.133881},
#  '79593': {'title': 'The Tie That Binds',
#   'budget': '14000000',
#   'vote_count': 9.0,
#   'vote_avg': 4.6,
#   'revenue': 5780000.0,
#   'genres': [' Thriller'],
#   'runtime': 99.0,
#   'popularity': 1.8204189999999998},
#  '47939': {'title': 'Three Wishes',
#   'budget': '0',
#   'vote_count': 18.0,
#   'vote_avg': 6.1,
#   'revenue': 7025496.0,
#   'genres': [' Drama', ' Fantasy'],
#   'runtime': 115.0,
#   'popularity': 11.002046},
#  '36834': {'title': 'Total Eclipse',
#   'budget': '0',
#   'vote_count': 112.0,
#   'vote_avg': 6.5,
#   'revenue': 339889.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 111.0,
#   'popularity': 4.546551999999999},
#  '9090': {'title': 'To Wong Foo, Thanks for Everything! Julie Newmar',
#   'budget': '0',
#   'vote_count': 117.0,
#   'vote_avg': 6.3,
#   'revenue': 47774193.0,
#   'genres': [' Comedy'],
#   'runtime': 105.0,
#   'popularity': 7.653446000000001},
#  '3512': {'title': 'Under Siege 2: Dark Territory',
#   'budget': '60000000',
#   'vote_count': 217.0,
#   'vote_avg': 5.6,
#   'revenue': 104324083.0,
#   'genres': [' Action', ' Thriller'],
#   'runtime': 100.0,
#   'popularity': 7.490247},
#  '52856': {'title': 'Unstrung Heroes',
#   'budget': '0',
#   'vote_count': 9.0,
#   'vote_avg': 6.4,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Drama', ' Family'],
#   'runtime': 93.0,
#   'popularity': 2.8816889999999997},
#  '77350': {'title': 'Unzipped',
#   'budget': '0',
#   'vote_count': 6.0,
#   'vote_avg': 6.0,
#   'revenue': 0.0,
#   'genres': [' Documentary'],
#   'runtime': 73.0,
#   'popularity': 0.7860229999999999},
#  '9560': {'title': 'A Walk in the Clouds',
#   'budget': '20000000',
#   'vote_count': 168.0,
#   'vote_avg': 6.5,
#   'revenue': 50012507.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 103.0,
#   'popularity': 9.715639},
#  '9804': {'title': 'Waterworld',
#   'budget': '175000000',
#   'vote_count': 1017.0,
#   'vote_avg': 5.9,
#   'revenue': 264218220.0,
#   'genres': [' Adventure', ' Action'],
#   'runtime': 135.0,
#   'popularity': 16.885184},
#  '31611': {'title': "White Man's Burden",
#   'budget': '8000000',
#   'vote_count': 25.0,
#   'vote_avg': 5.1,
#   'revenue': 0.0,
#   'genres': [' Drama'],
#   'runtime': 89.0,
#   'popularity': 1.8340990000000001},
#  '65796': {'title': 'Wild Bill',
#   'budget': '30000000',
#   'vote_count': 27.0,
#   'vote_avg': 5.9,
#   'revenue': 0.0,
#   'genres': [' Action', ' Western'],
#   'runtime': 98.0,
#   'popularity': 8.922139},
#  '49805': {'title': 'The Browning Version',
#   'budget': '0',
#   'vote_count': 11.0,
#   'vote_avg': 6.0,
#   'revenue': 0.0,
#   'genres': [' Drama'],
#   'runtime': 97.0,
#   'popularity': 3.727644},
#  '26258': {'title': 'Bushwhacked',
#   'budget': '0',
#   'vote_count': 29.0,
#   'vote_avg': 4.9,
#   'revenue': 0.0,
#   'genres': [' Adventure', ' Action', ' Comedy', ' Crime', ' Family'],
#   'runtime': 90.0,
#   'popularity': 3.287036},
#  '50797': {'title': 'Утомлённые солнцем',
#   'budget': '2800000',
#   'vote_count': 35.0,
#   'vote_avg': 6.7,
#   'revenue': 2616503.0,
#   'genres': [' Drama'],
#   'runtime': 135.0,
#   'popularity': 2.4860729999999998},
#  '19155': {'title': 'Before the Rain',
#   'budget': '0',
#   'vote_count': 45.0,
#   'vote_avg': 7.7,
#   'revenue': 763847.0,
#   'genres': [' Drama', ' War'],
#   'runtime': 113.0,
#   'popularity': 3.5256489999999996},
#  '76': {'title': 'Before Sunrise',
#   'budget': '2500000',
#   'vote_count': 984.0,
#   'vote_avg': 7.7,
#   'revenue': 5535405.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 105.0,
#   'popularity': 11.304979},
#  '11017': {'title': 'Billy Madison',
#   'budget': '10000000',
#   'vote_count': 464.0,
#   'vote_avg': 6.2,
#   'revenue': 26488734.0,
#   'genres': [' Comedy'],
#   'runtime': 89.0,
#   'popularity': 6.638116},
#  '37141': {'title': 'The Babysitter',
#   'budget': '0',
#   'vote_count': 27.0,
#   'vote_avg': 4.7,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Thriller'],
#   'runtime': 90.0,
#   'popularity': 2.761837},
#  '9382': {'title': 'Boys on the Side',
#   'budget': '21000000',
#   'vote_count': 48.0,
#   'vote_avg': 6.3,
#   'revenue': 23450000.0,
#   'genres': [' Comedy', ' Drama'],
#   'runtime': 115.0,
#   'popularity': 3.030309},
#  '6715': {'title': 'The Cure',
#   'budget': '0',
#   'vote_count': 58.0,
#   'vote_avg': 7.2,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Family'],
#   'runtime': 97.0,
#   'popularity': 2.686342},
#  '18256': {'title': 'Castle Freak',
#   'budget': '0',
#   'vote_count': 40.0,
#   'vote_avg': 5.8,
#   'revenue': 0.0,
#   'genres': [' Thriller', ' Drama', ' Horror', ' Mystery'],
#   'runtime': 95.0,
#   'popularity': 2.2697700000000003},
#  '22625': {'title': 'Circle of Friends',
#   'budget': '0',
#   'vote_count': 30.0,
#   'vote_avg': 6.5,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Family', ' Romance'],
#   'runtime': 103.0,
#   'popularity': 2.605521},
#  '2292': {'title': 'Clerks',
#   'budget': '27000',
#   'vote_count': 769.0,
#   'vote_avg': 7.4,
#   'revenue': 3151130.0,
#   'genres': [' Comedy'],
#   'runtime': 92.0,
#   'popularity': 10.513367},
#  '1909': {'title': 'Don Juan DeMarco',
#   'budget': '25000000',
#   'vote_count': 184.0,
#   'vote_avg': 6.3,
#   'revenue': 22200000.0,
#   'genres': [' Romance', ' Drama', ' Comedy'],
#   'runtime': 97.0,
#   'popularity': 7.438934},
#  '8984': {'title': 'Disclosure',
#   'budget': '55000000',
#   'vote_count': 217.0,
#   'vote_avg': 5.9,
#   'revenue': 214015089.0,
#   'genres': [' Drama', ' Thriller', ' Crime', ' Mystery', ' Romance'],
#   'runtime': 123.0,
#   'popularity': 11.812244},
#  '61813': {'title': 'Dream Man',
#   'budget': '0',
#   'vote_count': 1.0,
#   'vote_avg': 2.5,
#   'revenue': 0.0,
#   'genres': [' Thriller'],
#   'runtime': 0.0,
#   'popularity': 0.155859},
#  '4954': {'title': 'Drop Zone',
#   'budget': '45000000',
#   'vote_count': 91.0,
#   'vote_avg': 5.1,
#   'revenue': 0.0,
#   'genres': [' Action', ' Adventure', ' Thriller'],
#   'runtime': 101.0,
#   'popularity': 9.579155},
#  '62488': {'title': 'Destiny Turns on the Radio',
#   'budget': '0',
#   'vote_count': 9.0,
#   'vote_avg': 5.3,
#   'revenue': 0.0,
#   'genres': [' Crime', ' Comedy', ' Fantasy'],
#   'runtime': 0.0,
#   'popularity': 0.710671},
#  '10531': {'title': 'Death and the Maiden',
#   'budget': '0',
#   'vote_count': 92.0,
#   'vote_avg': 7.1,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Thriller', ' Mystery'],
#   'runtime': 103.0,
#   'popularity': 5.484156},
#  '11929': {'title': 'Dolores Claiborne',
#   'budget': '0',
# ...
#   'budget': '6000000',
#   'vote_count': 85.0,
#   'vote_avg': 6.5,
#   'revenue': 42000000.0,
#   'genres': [' Adventure', ' Comedy', ' Family', ' Fantasy', ' Romance'],
#   'runtime': 167.0,
#   'popularity': 6.164226},
#  '1585': {'title': "It's a Wonderful Life",
#   'budget': '3180000',
#   'vote_count': 1103.0,
#   'vote_avg': 8.0,
#   'revenue': 9644124.0,
#   'genres': [' Drama', ' Family', ' Fantasy'],
#   'runtime': 130.0,
#   'popularity': 15.031588000000001},
#  '3083': {'title': 'Mr. Smith Goes to Washington',
#   'budget': '1500000',
#   'vote_count': 245.0,
#   'vote_avg': 7.9,
#   'revenue': 9600000.0,
#   'genres': [' Comedy', ' Drama'],
#   'runtime': 129.0,
#   'popularity': 8.168694},
#  '900': {'title': 'Bringing Up Baby',
#   'budget': '1073000',
#   'vote_count': 201.0,
#   'vote_avg': 7.6,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Romance'],
#   'runtime': 102.0,
#   'popularity': 6.60577},
#  '43795': {'title': 'Penny Serenade',
#   'budget': '0',
#   'vote_count': 23.0,
#   'vote_avg': 6.4,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 119.0,
#   'popularity': 2.446972},
#  '85638': {'title': 'The Scarlet Letter',
#   'budget': '0',
#   'vote_count': 4.0,
#   'vote_avg': 8.3,
#   'revenue': 0.0,
#   'genres': [' Drama'],
#   'runtime': 115.0,
#   'popularity': 0.284522},
#  '50001': {'title': 'Lady of Burlesque',
#   'budget': '0',
#   'vote_count': 7.0,
#   'vote_avg': 5.0,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Thriller', ' Mystery', ' Romance'],
#   'runtime': 91.0,
#   'popularity': 0.26469499999999996},
#  '43905': {'title': 'Of Human Bondage',
#   'budget': '0',
#   'vote_count': 26.0,
#   'vote_avg': 6.4,
#   'revenue': 0.0,
#   'genres': [' Drama'],
#   'runtime': 83.0,
#   'popularity': 1.831221},
#  '22688': {'title': 'Angel on My Shoulder',
#   'budget': '0',
#   'vote_count': 6.0,
#   'vote_avg': 5.7,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Fantasy', ' Romance'],
#   'runtime': 100.0,
#   'popularity': 0.594433},
#  '23114': {'title': 'Little Lord Fauntleroy',
#   'budget': '0',
#   'vote_count': 13.0,
#   'vote_avg': 6.6,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Family'],
#   'runtime': 102.0,
#   'popularity': 4.709847},
#  '26378': {'title': 'They Made Me a Criminal',
#   'budget': '0',
#   'vote_count': 8.0,
#   'vote_avg': 5.6,
#   'revenue': 0.0,
#   'genres': [' Thriller', ' Crime', ' Drama', ' Mystery'],
#   'runtime': 92.0,
#   'popularity': 1.758391},
#  '40206': {'title': 'The Inspector General',
#   'budget': '0',
#   'vote_count': 17.0,
#   'vote_avg': 6.2,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Music', ' Romance'],
#   'runtime': 101.0,
#   'popularity': 0.8965049999999999},
#  '22356': {'title': 'Angel and the Badman',
#   'budget': '0',
#   'vote_count': 27.0,
#   'vote_avg': 6.6,
#   'revenue': 0.0,
#   'genres': [' Romance', ' Western'],
#   'runtime': 100.0,
#   'popularity': 8.08426},
#  '260': {'title': 'The 39 Steps',
#   'budget': '0',
#   'vote_count': 217.0,
#   'vote_avg': 7.4,
#   'revenue': 0.0,
#   'genres': [' Action', ' Thriller', ' Mystery'],
#   'runtime': 86.0,
#   'popularity': 5.865697},
#  '43488': {'title': 'A Walk in the Sun',
#   'budget': '0',
#   'vote_count': 14.0,
#   'vote_avg': 5.2,
#   'revenue': 0.0,
#   'genres': [' War', ' Drama'],
#   'runtime': 117.0,
#   'popularity': 8.85591},
#  '22613': {'title': 'The Outlaw',
#   'budget': '0',
#   'vote_count': 16.0,
#   'vote_avg': 4.9,
#   'revenue': 0.0,
#   'genres': [' Action', ' Adventure', ' Western'],
#   'runtime': 116.0,
#   'popularity': 1.4509889999999999},
#  '10331': {'title': 'Night of the Living Dead',
#   'budget': '114000',
#   'vote_count': 591.0,
#   'vote_avg': 7.5,
#   'revenue': 30000000.0,
#   'genres': [' Horror'],
#   'runtime': 96.0,
#   'popularity': 14.384198000000001},
#  '488': {'title': 'The African Queen',
#   'budget': '1300000',
#   'vote_count': 232.0,
#   'vote_avg': 7.4,
#   'revenue': 10750000.0,
#   'genres': [' Adventure', ' War', ' Romance'],
#   'runtime': 105.0,
#   'popularity': 6.636872},
#  '22733': {'title': 'Beat the Devil',
#   'budget': '1000000',
#   'vote_count': 31.0,
#   'vote_avg': 6.2,
#   'revenue': 0.0,
#   'genres': [' Action',
#    ' Adventure',
#    ' Comedy',
#    ' Crime',
#    ' Drama',
#    ' Romance'],
#   'runtime': 89.0,
#   'popularity': 2.001733},
#  '261': {'title': 'Cat on a Hot Tin Roof',
#   'budget': '3000000',
#   'vote_count': 168.0,
#   'vote_avg': 7.6,
#   'revenue': 17570324.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 108.0,
#   'popularity': 11.794846000000001},
#  '57575': {'title': 'The Last Time I Saw Paris',
#   'budget': '0',
#   'vote_count': 9.0,
#   'vote_avg': 5.1,
#   'revenue': 105.0,
#   'genres': [' Romance', ' Drama'],
#   'runtime': 116.0,
#   'popularity': 0.912955},
#  '32574': {'title': 'Meet John Doe',
#   'budget': '0',
#   'vote_count': 52.0,
#   'vote_avg': 7.3,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Comedy', ' Romance'],
#   'runtime': 122.0,
#   'popularity': 10.750619},
#  '22657': {'title': 'Algiers',
#   'budget': '0',
#   'vote_count': 6.0,
#   'vote_avg': 5.8,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Action', ' Mystery', ' Romance'],
#   'runtime': 96.0,
#   'popularity': 0.348765},
#  '76464': {'title': 'Something to Sing About',
#   'budget': '0',
#   'vote_count': 2.0,
#   'vote_avg': 3.8,
#   'revenue': 0.0,
#   'genres': [' Comedy'],
#   'runtime': 93.0,
#   'popularity': 0.367546},
#  '22649': {'title': 'A Farewell to Arms',
#   'budget': '4',
#   'vote_count': 29.0,
#   'vote_avg': 6.2,
#   'revenue': 25.0,
#   'genres': [' Drama', ' Romance', ' War'],
#   'runtime': 89.0,
#   'popularity': 1.914697},
#  '176841': {'title': 'Moonlight Murder',
#   'budget': '0',
#   'vote_count': 1.0,
#   'vote_avg': 6.0,
#   'revenue': 0.0,
#   'genres': [' Music', ' Mystery'],
#   'runtime': 65.0,
#   'popularity': 0.283269},
#  '125587': {'title': 'Nothing Personal',
#   'budget': '0',
#   'vote_count': 1.0,
#   'vote_avg': 4.0,
#   'revenue': 0.0,
#   'genres': [' Drama'],
#   'runtime': 83.0,
#   'popularity': 0.064512},
#  '39448': {'title': 'Huang jia shi jie',
#   'budget': '0',
#   'vote_count': 11.0,
#   'vote_avg': 7.4,
#   'revenue': 0.0,
#   'genres': [' Action', ' Foreign'],
#   'runtime': 93.0,
#   'popularity': 1.0600969999999998},
#  '52855': {'title': 'Dangerous Ground',
#   'budget': '0',
#   'vote_count': 8.0,
#   'vote_avg': 5.0,
#   'revenue': 3028094.0,
#   'genres': [' Drama'],
#   'runtime': 95.0,
#   'popularity': 1.463219},
#  '39940': {'title': 'Picnic',
#   'budget': '0',
#   'vote_count': 19.0,
#   'vote_avg': 6.7,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 115.0,
#   'popularity': 8.500509},
#  '172868': {'title': 'Madagascar Skin',
#   'budget': '0',
#   'vote_count': 0.0,
#   'vote_avg': 0.0,
#   'revenue': 0.0,
#   'genres': [],
#   'runtime': 96.0,
#   'popularity': 0.580724},
#  '85328': {'title': 'The Pompatus of Love',
#   'budget': '0',
#   'vote_count': 2.0,
#   'vote_avg': 5.3,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Romance', ' Drama'],
#   'runtime': 99.0,
#   'popularity': 0.537795},
#  '124632': {'title': 'Small Wonders',
#   'budget': '0',
#   'vote_count': 0.0,
#   'vote_avg': 0.0,
#   'revenue': 0.0,
#   'genres': [' Documentary', ' Family'],
#   'runtime': 77.0,
#   'popularity': 0.00264},
#  '11076': {'title': 'Fly Away Home',
#   'budget': '0',
#   'vote_count': 114.0,
#   'vote_avg': 6.6,
#   'revenue': 0.0,
#   'genres': [' Action', ' Adventure', ' Drama', ' Family'],
#   'runtime': 107.0,
#   'popularity': 5.5111550000000005},
#  '63945': {'title': 'Bliss',
#   'budget': '0',
#   'vote_count': 6.0,
#   'vote_avg': 4.8,
#   'revenue': 294064.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 103.0,
#   'popularity': 1.262649},
#  '58985': {'title': 'Grace of My Heart',
#   'budget': '0',
#   'vote_count': 15.0,
#   'vote_avg': 6.5,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Comedy', ' Music'],
#   'runtime': 116.0,
#   'popularity': 9.364417999999999},
#  '890': {'title': 'Schlafes Bruder',
#   'budget': '0',
#   'vote_count': 6.0,
#   'vote_avg': 6.8,
#   'revenue': 0.0,
#   'genres': [' Drama'],
#   'runtime': 127.0,
#   'popularity': 0.751733},
#  '10861': {'title': 'Maximum Risk',
#   'budget': '25000000',
#   'vote_count': 104.0,
#   'vote_avg': 5.3,
#   'revenue': 51702483.0,
#   'genres': [' Action', ' Adventure', ' Thriller'],
#   'runtime': 100.0,
#   'popularity': 7.370163000000001},
#  '1770': {'title': 'Michael Collins',
#   'budget': '28000000',
#   'vote_count': 98.0,
#   'vote_avg': 6.8,
#   'revenue': 16900000.0,
#   'genres': [' Drama', ' Thriller'],
#   'runtime': 132.0,
#   'popularity': 6.728199000000001},
#  '44465': {'title': "The Rich Man's Wife",
#   'budget': '0',
#   'vote_count': 11.0,
#   'vote_avg': 4.9,
#   'revenue': 8538318.0,
#   'genres': [' Drama', ' Thriller'],
#   'runtime': 94.0,
#   'popularity': 6.746475},
#  '2033': {'title': 'Infinity',
#   'budget': '0',
#   'vote_count': 0.0,
#   'vote_avg': 0.0,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Romance'],
#   'runtime': 119.0,
#   'popularity': 1.226688},
#  '18203': {'title': 'Big Night',
#   'budget': '0',
#   'vote_count': 45.0,
#   'vote_avg': 6.8,
#   'revenue': 0.0,
#   'genres': [' Drama'],
#   'runtime': 107.0,
#   'popularity': 2.702973},
#  '9333': {'title': 'Last Man Standing',
#   'budget': '67000000',
#   'vote_count': 263.0,
#   'vote_avg': 6.2,
#   'revenue': 47267001.0,
#   'genres': [' Action', ' Crime', ' Drama', ' Thriller'],
#   'runtime': 101.0,
#   'popularity': 11.845918},
#  '47260': {'title': 'Caught',
#   'budget': '0',
#   'vote_count': 5.0,
#   'vote_avg': 6.5,
#   'revenue': 0.0,
#   'genres': [' Action', ' Drama', ' Thriller'],
#   'runtime': 110.0,
#   'popularity': 1.625873},
#  '9400': {'title': 'Set It Off',
#   'budget': '9000000',
#   'vote_count': 66.0,
#   'vote_avg': 6.9,
#   'revenue': 41590886.0,
#   'genres': [' Drama', ' Action', ' Crime'],
#   'runtime': 118.0,
#   'popularity': 6.85606},
#  '9401': {'title': '2 Days in the Valley',
#   'budget': '0',
#   'vote_count': 73.0,
#   'vote_avg': 5.9,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Crime'],
#   'runtime': 104.0,
#   'popularity': 4.989276},
#  '12241': {'title': 'Curdled',
#   'budget': '2300000',
#   'vote_count': 29.0,
#   'vote_avg': 6.2,
#   'revenue': 49620.0,
#   'genres': [' Comedy', ' Crime', ' Thriller'],
#   'runtime': 88.0,
#   'popularity': 2.781581},
#  '25739': {'title': "L'associé",
#   'budget': '0',
#   'vote_count': 3.0,
#   'vote_avg': 6.0,
#   'revenue': 0.0,
#   'genres': [' Comedy'],
#   'runtime': 94.0,
#   'popularity': 0.000308},
#  '161806': {'title': "Ed's Next Move",
#   'budget': '0',
#   'vote_count': 1.0,
#   'vote_avg': 3.0,
#   'revenue': 0.0,
#   'genres': [],
#   'runtime': 88.0,
#   'popularity': 0.5502779999999999},
#  '11306': {'title': 'Extreme Measures',
#   'budget': '38000000',
#   'vote_count': 80.0,
#   'vote_avg': 5.7,
#   'revenue': 17380126.0,
#   'genres': [' Drama', ' Thriller'],
#   'runtime': 118.0,
#   'popularity': 4.990506},
#  '9625': {'title': 'The Glimmer Man',
#   'budget': '45000000',
#   'vote_count': 102.0,
#   'vote_avg': 4.7,
#   'revenue': 0.0,
#   'genres': [' Action', ' Adventure', ' Crime', ' Drama', ' Thriller'],
#   'runtime': 92.0,
#   'popularity': 5.918737},
#  '10680': {'title': 'D3: The Mighty Ducks',
#   'budget': '0',
#   'vote_count': 99.0,
#   'vote_avg': 5.3,
#   'revenue': 22955097.0,
#   'genres': [' Action', ' Comedy', ' Drama', ' Family'],
#   'runtime': 104.0,
#   'popularity': 5.511475},
#  '6346': {'title': 'The Chamber',
#   'budget': '50000000',
#   'vote_count': 62.0,
#   'vote_avg': 5.9,
#   'revenue': 22540359.0,
#   'genres': [' Crime', ' Drama'],
#   'runtime': 113.0,
#   'popularity': 3.9984940000000004},
#  '18660': {'title': 'The Apple Dumpling Gang',
#   'budget': '0',
#   'vote_count': 34.0,
#   'vote_avg': 6.6,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Family'],
#   'runtime': 100.0,
#   'popularity': 4.040945},
#  '35115': {'title': 'Davy Crockett, King of the Wild Frontier',
#   'budget': '0',
#   'vote_count': 14.0,
#   'vote_avg': 5.9,
#   'revenue': 0.0,
#   'genres': [' Action', ' Adventure', ' Family', ' Western'],
#   'runtime': 93.0,
#   'popularity': 5.497358999999999},
#  '14821': {'title': 'Escape to Witch Mountain',
#   'budget': '0',
#   'vote_count': 60.0,
#   'vote_avg': 6.5,
#   'revenue': 20000000.0,
#   'genres': [' Adventure', ' Fantasy', ' Science Fiction', ' Family'],
#   'runtime': 97.0,
#   'popularity': 7.1516910000000005},
#  '14136': {'title': 'The Love Bug',
#   'budget': '0',
#   'vote_count': 126.0,
#   'vote_avg': 6.0,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Family', ' Fantasy'],
#   'runtime': 107.0,
#   'popularity': 10.091707000000001},
#  '10869': {'title': 'Herbie Rides Again',
#   'budget': '0',
#   'vote_count': 77.0,
#   'vote_avg': 5.9,
#   'revenue': 0.0,
#   'genres': [' Romance', ' Comedy', ' Family', ' Fantasy'],
#   'runtime': 88.0,
#   'popularity': 4.914603},
#  '22660': {'title': 'Old Yeller',
#   'budget': '0',
#   'vote_count': 68.0,
#   'vote_avg': 7.0,
#   'revenue': 0.0,
#   'genres': [' Adventure', ' Drama', ' Western'],
#   'runtime': 83.0,
#   'popularity': 12.887829},
#  '19186': {'title': 'The Parent Trap',
#   'budget': '0',
#   'vote_count': 92.0,
#   'vote_avg': 6.8,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Family'],
#   'runtime': 129.0,
#   'popularity': 5.807074},
#  '31102': {'title': 'Pollyanna',
#   'budget': '0',
#   'vote_count': 50.0,
#   'vote_avg': 6.9,
#   'revenue': 0.0,
#   'genres': [' Adventure'],
#   'runtime': 134.0,
#   'popularity': 3.254308},
#  '6878': {'title': 'Homeward Bound: The Incredible Journey',
#   'budget': '0',
#   'vote_count': 218.0,
#   'vote_avg': 6.6,
#   'revenue': 0.0,
#   'genres': [' Adventure', ' Comedy', ' Drama', ' Family'],
#   'runtime': 84.0,
#   'popularity': 7.186506},
#  '15944': {'title': 'The Shaggy Dog',
#   'budget': '0',
#   'vote_count': 22.0,
#   'vote_avg': 6.2,
#   'revenue': 0.0,
#   'genres': [' Comedy', ' Family'],
#   'runtime': 104.0,
#   'popularity': 3.404213},
#  '18444': {'title': 'Swiss Family Robinson',
#   'budget': '0',
#   'vote_count': 88.0,
#   'vote_avg': 7.0,
#   'revenue': 0.0,
#   'genres': [' Adventure', ' Family'],
#   'runtime': 126.0,
#   'popularity': 4.623089},
#  '20723': {'title': 'That Darn Cat!',
#   'budget': '0',
#   'vote_count': 28.0,
#   'vote_avg': 6.4,
#   'revenue': 0.0,
#   'genres': [' Drama', ' Family', ' Comedy'],
#   'runtime': 112.0,
#   'popularity': 2.8036790000000003},
#  '173': {'title': '20,000 Leagues Under the Sea',
#   'budget': '5000000',
#   'vote_count': 160.0,
#   'vote_avg': 6.9,
#   'revenue': 28200000.0,
#   'genres': [' Adventure', ' Drama', ' Science Fiction'],
#   'runtime': 127.0,
#   'popularity': 8.722406},
#  '864': {'title': 'Cool Runnings',
#   'budget': '14000000',
#   'vote_count': 510.0,
#   'vote_avg': 6.8,
#   'revenue': 154864401.0,
#   'genres': [' Comedy'],
#   'runtime': 98.0,
#   'popularity': 8.307210000000001},
#  '24795': {'title': 'Angels in the Outfield',
#   'budget': '0',
#   'vote_count': 124.0,
#   'vote_avg': 5.7,
#   'revenue': 50236831.0,
#   'genres': [' Fantasy', ' Drama', ' Comedy', ' Family'],
#   'runtime': 102.0,
#   'popularity': 10.892812},
#  '11224': {'title': 'Cinderella',
#   'budget': '2900000',
#   'vote_count': 1760.0,
#   'vote_avg': 6.8,
#   'revenue': 263591415.0,
#   'genres': [' Family', ' Fantasy', ' Animation', ' Romance'],
#   'runtime': 74.0,
#   'popularity': 14.436857999999999},
#  '81310': {'title': 'Winnie the Pooh and the Blustery Day',
#   'budget': '0',
#   'vote_count': 20.0,
#   'vote_avg': 7.8,
#   'revenue': 0.0,
#   'genres': [' Animation', ' Family', ' Music'],
#   'runtime': 25.0,
#   'popularity': 1.054814},
#  '15947': {'title': 'The Three Caballeros',
#   'budget': '0',
#   'vote_count': 108.0,
#   'vote_avg': 6.2,
#   'revenue': 0.0,
#   'genres': [' Animation', ' Family', ' Music'],
#   'runtime': 71.0,
#   'popularity': 8.702472},
#  '9078': {'title': 'The Sword in the Stone',
#   'budget': '3000000',
#   'vote_count': 935.0,
#   'vote_avg': 6.9,
#   'revenue': 22182353.0,
#   'genres': [' Animation', ' Family'],
#   'runtime': 79.0,
#   'popularity': 10.636458},
#  '29682': {'title': 'So Dear to My Heart',
#   'budget': '0',
#   'vote_count': 5.0,
#   'vote_avg': 6.3,
#   'revenue': 0.0,
#   'genres': [' Animation', ' Drama', ' Family'],
#   'runtime': 79.0,
#   'popularity': 0.901443},
#  '8367': {'title': 'Robin Hood: Prince of Thieves',
#   'budget': '48000000',
#   'vote_count': 937.0,
#   'vote_avg': 6.6,
#   'revenue': 390493908.0,
#   'genres': [' Adventure'],
#   'runtime': 143.0,
#   'popularity': 10.639244},
#  '433': {'title': 'Mary Poppins',
#   'budget': '6000000',
#   'vote_count': 1217.0,
#   'vote_avg': 7.4,
#   'revenue': 102272727.0,
#   'genres': [' Comedy', ' Family', ' Fantasy'],
#   'runtime': 139.0,
#   'popularity': 15.11549}}

# %%
print(movies_dict['862'])
# Out:
# {'title': 'Toy Story', 'budget': '30000000', 'vote_count': 5415.0, 'vote_avg': 7.7, 'revenue': 373554033.0, 'genres': [' Animation', ' Comedy', ' Family'], 'runtime': 81.0, 'popularity': 21.946943}

# %%
movie_revenue_dict = sort_movies_by_attr(movies_dict, 'revenue')

# %% [markdown]
# ### Some visualizations

# %%
attr_list = ['revenue', 'budget', 'popularity', 'vote_count', 'vote_avg']
title_list = ['Filmes com maior receita', 
              'Filmes com maior despesa', 
              'Filmes mais populares', 
              'Filmes mais avaliados',
              'Filmes com melhor avaliação']
i=0
k=10  #top-k for an attr
for attr in attr_list:
    movies_attr_dict = sort_movies_by_attr(movies_dict, attr, True)
    
    movies = list(movies_attr_dict.keys())[:k]  #TODO: remove id from movies
    attrs  = list(movies_attr_dict.values())[:k]
    plt.figure(figsize=(10,8))
    plt.bar(movies, attrs, align='center', alpha=0.5)
    plt.xticks(rotation=90)
    plt.ylabel(attr)
    plt.title(title_list[i])
    plt.show()
    i+=1

# %%
runtime_dict = build_movie_attr_dict(movies_dict, 'runtime')

plt.figure(figsize=(10,8))
plt.hist(runtime_dict.values(), bins=30)
plt.show()
# Out:
# /home/romulo/anaconda3/lib/python3.6/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/romulo/anaconda3/lib/python3.6/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# %%time
genres_dict = build_movie_attr_dict(movies_dict, 'genres')


genres2plot = dict()
for movie, genres in genres_dict.items():
    for genre in genres:
        genre = genre[1:]
        if genre in genres2plot:
            genres2plot[genre] += 1
        else:
            genres2plot[genre] = 1
# Out:
# CPU times: user 4.35 ms, sys: 31 µs, total: 4.38 ms
# Wall time: 4.34 ms

# %%
genres2plot
# Out:
# {'Animation': 31,
#  'Comedy': 376,
#  'Family': 131,
#  'Adventure': 110,
#  'Fantasy': 78,
#  'Romance': 259,
#  'Drama': 570,
#  'Action': 169,
#  'Crime': 130,
#  'Thriller': 212,
#  'Horror': 43,
#  'History': 28,
#  'Science Fiction': 63,
#  'Mystery': 76,
#  'War': 30,
#  'Foreign': 17,
#  'Music': 29,
#  'Documentary': 23,
#  'Western': 21,
#  'TV Movie': 2}

# %%
genres2plot = {k: v for k, v in sorted(genres2plot.items(), key=lambda item: item[1], reverse=True)}
genres2plot
# Out:
# {'Drama': 570,
#  'Comedy': 376,
#  'Romance': 259,
#  'Thriller': 212,
#  'Action': 169,
#  'Family': 131,
#  'Crime': 130,
#  'Adventure': 110,
#  'Fantasy': 78,
#  'Mystery': 76,
#  'Science Fiction': 63,
#  'Horror': 43,
#  'Animation': 31,
#  'War': 30,
#  'Music': 29,
#  'History': 28,
#  'Documentary': 23,
#  'Western': 21,
#  'Foreign': 17,
#  'TV Movie': 2}

# %%
genres = list(genres2plot.keys())
count  = list(genres2plot.values())

plt.figure(figsize=(10,8))
plt.bar(genres, count, align='center', alpha=0.5)
plt.xticks(rotation=90)
plt.ylabel('Quantidade de filmes')
plt.xlabel('Gênero')
plt.title('Quantidade de filmes por gênero')
plt.show()

# %%
k = 10
genres = list(genres2plot.keys())[:k]
count  = list(genres2plot.values())[:k]

plt.figure(figsize=(10,8))
plt.bar(genres, count, align='center', alpha=0.5)
plt.xticks(rotation=90)
plt.ylabel('Quantidade de filmes')
plt.xlabel('Gênero')
plt.title('Quantidade de filmes por gênero')
plt.show()
